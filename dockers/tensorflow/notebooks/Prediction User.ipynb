# %%
import tensorflow as tf

# %%
dataset = tf.data.TextLineDataset(["/tf/data/event.csv"])
for element in dataset: 
  print(element)
# Out:
# tf.Tensor(b'id,id_place,description,date', shape=(), dtype=string)
# tf.Tensor(b'bbbbbbb82y,aaaGL,awsome event in Bar Santurce N\xc2\xba: 0,1599849000', shape=(), dtype=string)
# tf.Tensor(b'bbbbbbb82z,aaaGL,awsome event in Bar Santurce N\xc2\xba: 1,1590690600', shape=(), dtype=string)
# tf.Tensor(b'bbbbbbb82A,aaaGL,awsome event in Bar Santurce N\xc2\xba: 2,1599849000', shape=(), dtype=string)
# tf.Tensor(b'bbbbbbb82B,aaaGL,awsome event in Bar Santurce N\xc2\xba: 3,1583436600', shape=(), dtype=string)
# tf.Tensor(b'bbbbbbb82C,aaaGL,awsome event in Bar Santurce N\xc2\xba: 4,1595183400', shape=(), dtype=string)
# tf.Tensor(b'bbbbbbb82D,aaaGL,awsome event in Bar Santurce N\xc2\xba: 5,1605555000', shape=(), dtype=string)
# tf.Tensor(b'bbbbbbb82E,aaaGL,awsome event in Bar Santurce N\xc2\xba: 6,1589394600', shape=(), dtype=string)
# tf.Tensor(b'bbbbbbb82F,aaaGL,awsome event in Bar Santurce N\xc2\xba: 7,1594146600', shape=(), dtype=string)
# ...
